# %%
import requests
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import urllib.request

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'}
url = "https://yocket.in/applications-admits-rejects/university-of-california-riverside/2"

# %%
page = requests.get(url,headers= headers, verify = False)
page_soup = soup(page.content,'lxml')
course = page_soup.findAll("div",{"class":"col-sm-9"})
course
# Out:
# C:\Users\lakshmib\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# [<div class="col-sm-9">
#  <script>
#  		try{
#  			localStorage.setItem("universityCourseId", 665);
#  			localStorage.setItem("universityUrlAlias", );
#  		}
#  		catch(err){
#  			console.log('Handled! university alias');
#  		}
#      </script>
#  <h1>Admits from University of California, Riverside</h1><hr/>
#  <div class="well">
#  <h4>Find admits &amp; rejects</h4><p>Check profiles and test scores (GRE, GMAT, TOEFL, IELTS...) of students who got an admit from University of California, Riverside for Fall 2018 and Spring 2018</p><hr/>
#  <ul class="alert alert-danger" id="admits-rejects-error" style="display: none;padding-left: 30px">
#  </ul>
#  <div class="ui-widget col-sm-4">
#  <div class="input-group">
#  <span class="input-group-addon" style="background: #fff;"><i class="fa fa-university" id="users-view-search-universities-icon"></i></span>
#  <input aria-describedby="users-view-search-universities" autocomplete="off" class="form-control" id="users-view-search-universities" placeholder="University name" type="text" value="University of California,  Riverside"/>
#  </div>
#  </div>
#  <div class="ui-widget col-sm-4">
#  <div class="input-group">
#  <span class="input-group-addon" style="background: #fff;"><i class="fa fa-file-text" id="users-view-search-courses-icon"></i></span>
#  <input aria-describedby="users-view-search-courses" autocomplete="off" class="form-control" disabled="disabled" id="users-view-search-courses" placeholder="Grad course name" type="text" value=""/>
#  </div>
#  </div>
#  <div class="input-group col-sm-4">
#  <div class="input-group-addon">Status</div>
#  <select class="form-control" id="university-application-status" name="university-application-status"><option value="0">Choose status</option><option value="1">Applied</option><option selected="selected" value="2">Admit</option><option value="3">Reject</option><option value="4">Interested</option></select> </div>
#  <input id="user-id" type="hidden" value=""/>
#  <br/>
#  <div class="text-center">
#  <button class="btn btn-success btn-sm" id="find-admits-rejects-button" type="button"> FIND </button>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/animeshnikam">animeshnikam</a><br/>
#  <small>
#  University of California, Riverside <br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  309 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  102 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  64 % </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  NA </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/prajnaira">prajnaira</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  N.A. </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>ENG TEST</strong><br/>
#  NA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  9.21 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  6 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Scater">Scater</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  317 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>ENG TEST</strong><br/>
#  NA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  2.7 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  22 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/HarshaP">HarshaP</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  307 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>IELTS</strong><br/>
#  7.5 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  8.44 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  NA </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/tharun21feb">tharun21feb</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  312 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  109 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  8.02 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  18 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/HarshaParuchuri">HarshaParuchuri</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  306 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>IELTS</strong><br/>
#  7.5 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  8.45 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  1 month </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Shradha09">Shradha09</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  313 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  96 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  73 % </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  NA </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/navjot">navjot</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#   Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  327 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  0 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  70 % </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  48 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/ashishvyasxpu">ashishvyasxpu</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  313 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  98 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  6.67 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  6 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/notavailble">notavailble</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  312 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>IELTS</strong><br/>
#  7 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  8.61 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  3 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/venkat sai">venkat sai</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  314 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  0 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.5 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  NA </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/IrfanV">IrfanV</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  320 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  111 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.49 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  29 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Arjav">Arjav</a><br/>
#  <small>
#  University of California, Riverside Computer Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  314 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  0 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.46 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  1 month </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/maddyyy">maddyyy</a><br/>
#  <small>
#  University of California, Riverside Management<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  N.A. </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>IELTS</strong><br/>
#  7 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  74 % </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  20 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/mustikovila">mustikovila</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  314 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  99 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.6 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  2 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Aashuuu">Aashuuu</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  310 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  95 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.97 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  2 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/abhishekaich27">abhishekaich27</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  N.A. </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>ENG TEST</strong><br/>
#  NA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  9 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  20 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/IshitaC">IshitaC</a><br/>
#  <small>
#  University of California, Riverside Computer Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  317 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  112 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.33 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  7 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="row"> <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/jeetrockers">jeetrockers</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  314 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>IELTS</strong><br/>
#  7 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  9.12 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  27 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="col-sm-6">
#  <div class="panel panel-warning">
#  <div class="panel-body">
#  <div class="row">
#  <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/monishk1001">monishk1001</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>
#  <div class="col-sm-3 text-uppercase">
#  <label class="label label-success">Admit</label><br/><br/>
#  </div>
#  </div>
#  <div class="row text-center">
#  <div class="col-sm-3 col-xs-6">
#  <strong>GRE</strong><br/>
#  319 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>TOEFL</strong><br/>
#  0 </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>UNDERGRAD</strong><br/>
#  7.35 CGPA </div>
#  <div class="col-sm-3 col-xs-6">
#  <strong>WORK EX</strong><br/>
#  4 months </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="clearfix"></div>
#  <div class="text-center">
#  <div class="paginator">
#  <ul class="pagination">
#  <li class="prev disabled"><a href="" onclick="return false;"><i class="fa fa-chevron-left"></i></a></li> <li class="active"><a href="">1</a></li><li><a href="/applications-admits-rejects/university-of-california-riverside/2?page=2">2</a></li><li><a href="/applications-admits-rejects/university-of-california-riverside/2?page=3">3</a></li><li><a href="/applications-admits-rejects/university-of-california-riverside/2?page=4">4</a></li><li><a href="/applications-admits-rejects/university-of-california-riverside/2?page=5">5</a></li> <li class="next"><a href="/applications-admits-rejects/university-of-california-riverside/2?page=2" rel="next"><i class="fa fa-chevron-right"></i></a></li> </ul>
#  </div>
#  </div>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/animeshnikam">animeshnikam</a><br/>
#  <small>
#  University of California, Riverside <br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/prajnaira">prajnaira</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Scater">Scater</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/HarshaP">HarshaP</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/tharun21feb">tharun21feb</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/HarshaParuchuri">HarshaParuchuri</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Shradha09">Shradha09</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/navjot">navjot</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#   Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/ashishvyasxpu">ashishvyasxpu</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/notavailble">notavailble</a><br/>
#  <small>
#  University of California, Riverside Computer Science<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/venkat sai">venkat sai</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/IrfanV">IrfanV</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Arjav">Arjav</a><br/>
#  <small>
#  University of California, Riverside Computer Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/maddyyy">maddyyy</a><br/>
#  <small>
#  University of California, Riverside Management<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/mustikovila">mustikovila</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/Aashuuu">Aashuuu</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/abhishekaich27">abhishekaich27</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/IshitaC">IshitaC</a><br/>
#  <small>
#  University of California, Riverside Computer Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/jeetrockers">jeetrockers</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>, <div class="col-sm-9">
#  <h4>
#  <a href="/profiles/monishk1001">monishk1001</a><br/>
#  <small>
#  University of California, Riverside Electrical Engineering<br/>
#  Fall 2018 </small>
#  </h4>
#  </div>]
