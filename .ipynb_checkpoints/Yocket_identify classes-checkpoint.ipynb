# %%
import requests
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import re
import urllib.request

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'}
url = "https://yocket.in/applications-admits-rejects/university-of-california-riverside/2"

# %%
request=urllib.request.Request(url,None,headers)

# %%
response = urllib.request.urlopen(request)
data = response.read() # The data u need
page_soup = soup(data,"lxml")

# %%
course = page_soup.findAll("div",{"class":"col-sm-9"})
course.

# %%
name = []
course = []
period = []
gre =[]
toefl = []
cgpa = []
workExp = []
ielts = []

# %%
#name, applied course and period of application
# name,course_name,period = []
courseTag = page_soup.findAll("div",{"class":"col-sm-9"})
for tag in courseTag:
    name.append(tag.find("a").text)
    course.append(tag.find("small").text)

# %%
course
# Out:
# ['\nUniversity of California, Riverside \nFall 2018 ',
#  '\nUniversity of California, Riverside \nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Science\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Management\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Computer Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ',
#  '\nUniversity of California, Riverside Electrical Engineering\nFall 2018 ']

# %%
#gre, toefel cgpa work experience
grading = page_soup.findAll("div",{"class" : "col-sm-3 col-xs-6"})
for tag in grading:
    heading = tag.find("strong").text
#     print(heading)
    data = tag.findNext("br").next_sibling
    if (heading == "GRE"):
        gre.append(data)
    
    elif(heading == "TOEFL" or heading == "IELTS" or heading == "ENG TEST"):
        toefl.append(data.string)
    
    elif("UNDERGRAD"):
        cgpa.append(data.string)
    
    elif("WORK EX"):
        workExp.append(data.string)
    
    elif ("IELTS"):
        ielts.append(data.string)

# %%
def getAdmitData(page_soup):
    name = []
    course = []
    period = []
    gre =[]
    toefl = []
    cgpa = []
    workExp = []
    ielts = []
    courseTag = page_soup.findAll("div",{"class":"col-sm-9"}) #div for name,Course(college,course,period)
    grading = page_soup.findAll("div",{"class" : "col-sm-3 col-xs-6"}) #div for gre,toefl,cgpa,work exp
    for tag in courseTag:
        name.append(tag.find("a").text) #Tag for name of student
        course.append(tag.find("small").text) #Tag for course
    for tag in grading:
        heading = tag.find("strong").text #name of column
        data = tag.findNext("br").next_sibling #value
        if (heading == "GRE"):
            gre.append(data)
    
        elif(heading == "TOEFL" or heading == "IELTS" or heading == "ENG TEST"):
            toefl.append(data.string)
    
        elif("UNDERGRAD"):
            cgpa.append(data.string)
    
        elif("WORK EX"):
            workExp.append(data.string)
    
        elif ("IELTS"):
            ielts.append(data.string)

# %%
student_url = "https://yocket.in/profiles/bodepudi"
headers = {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'}

# %%
#working
student_request=urllib.request.Request(student_url,None,headers)
student_response = urllib.request.urlopen(student_request)
student_data = student_response.read() # The data u need
student_soup = soup(student_data,"lxml")
student_soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Spring 2019 Student - GRE Score: 308, IELTS: 7, Undergrad: 81 % | Yocket</title>
# <meta content="Profile of study abroad  Spring 2019 student. GRE 308, Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam, Work Experience: 20 months, Interested in Computer Science and Engineering" name="description"/>
# <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script src="/cdn-cgi/apps/head/Mu6wVX4OcZ8KDPC4TGyjOacEUjg.js"></script><link href="/img/yocket.ico" rel="icon" type="image/x-icon"/><link href="/img/yocket.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//static.yocket.in" rel="dns-prefetch"/>
# <link href="//yocket.in" rel="dns-prefetch"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <meta content="#EF6C00" name="theme-color"/><link href="https://static.yocket.in/images/yocket_logo.png" rel="icon" sizes="192x192"/>
# <link href="/manifest.json" rel="manifest"/>
# <noscript class="css-links-wrapper">
# <!--<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" class="js-fa-async-stylesheets" media="meaningless-media-query" async="async"/>-->
# <link async="async" class="js-fa-async-stylesheets" href="https://use.fontawesome.com/releases/v5.1.1/css/all.css" media="meaningless-media-query" rel="stylesheet"/> <link async="async" class="js-fa-async-stylesheets" href="https://fonts.googleapis.com/css?family=Noto+Sans:400,700" media="meaningless-media-query" rel="stylesheet"/></noscript>
# <script defer="defer" src="https://static.yocket.in/js/vendor.js?v=2.28.36"></script><script type="text/javascript">
# 	window.base_url = 'https://yocket.in/';
# 	window.username = '';
# </script>
# <script>
# 	window.reqAnimFr =
# 		(typeof window.requestAnimationFrame === 'function')?
# 			(function(fn) { window.requestAnimationFrame(function() { fn(); }); }):
# 			(function(fn) { setTimeout(fn, 10); });
#
# 	// Full load(if loaded, call, else, wait for loading)
# 	window.onFullLoad = function(_onLoad) {
# 		// Is it already loaded?
# 		if([ 'complete', 'interactive' ].indexOf(document.readyState) !== -1) {
# 			requestAnimationFrame(_onLoad);
# 		} else {
# 			window.addEventListener('DOMContentLoaded', _onLoad);
# 		}
# 	};
#
# 	(function(doc, win, raf) {
# 		'use strict';
# 		window.Array.from= window.Array.from || function(arr) { return window.Array.prototype.slice.call(arr, 0); };
#
# 		var $deferedLinks= doc.querySelector('.css-links-wrapper');
#
# 		function applyCSS($el) { if($el.getAttribute('media') !== 'all') $el.setAttribute('media', 'all'); }
#
# 		window.lCSSAsync= function () {
# 			var cls= 'js-fa-async-stylesheets';
# 			var $asyncLinks= doc.querySelectorAll('.' + cls) || [];
#
# 			for(var i= 0; i< $asyncLinks.length; i++) {
# 				var $el = $asyncLinks[i];
# 				var isLoaded = true;
# 				$el.classList.remove(cls);
#
# 				for(var j= 0; j < doc.styleSheets.length; j++) {
# 					var s = doc.styleSheets[j];
# 					if(s.href === $el.href && !('cssRules' in s)) {
# 						$el.addEventListener('load', applyCSS.bind(null, $el));
# 						isLoaded = false;
# 						break;
# 					}
# 				}
#
# 				if(isLoaded) raf(applyCSS.bind(null, $el));
# 			}
# 		};
#
# 		function lCSSDef() {
# 			raf(function() {
# 				var $div= doc.createElement('div');
# 				$div.innerHTML= $deferedLinks? $deferedLinks.textContent: '';
# 				doc.head.appendChild($div);
# 				window.lCSSAsync();
# 			});
# 		}
# 		doc.addEventListener('DOMContentLoaded', lCSSDef);
# 	})(document, window, window.reqAnimFr);
# </script>
# <script crossorigin="anonymous" defer="" integrity="sha512-K1qjQ+NcF2TYO/eI3M6v8EiNYZfA95pQumfvcVrTHtwQVDG+aHRqLi/ETn2uB+1JqwYqVG3LIvdm9lj6imS/pQ==" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-61697801-2', 'auto');  ga('send', 'pageview');
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/118013234/yocket-right-1', [300, 250], 'div-gpt-ad-1486040951439-0').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-2', [300, 250], 'div-gpt-ad-1486040951439-1').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-3', [300, 250], 'div-gpt-ad-1486040951439-2').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-4', [300, 250], 'div-gpt-ad-1510292313192-3').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window,document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#      fbq('init', '2335918096634703');
#     fbq('track', 'PageView');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=129716877531675&amp;ev=PageView
#     &amp;noscript=1" width="1"/>
# </noscript>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.crossorigin='anonymous';
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.8&appId=812660582206420";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <link async="async" class="js-fa-async-stylesheets" href="https://static.yocket.in/css/style.css?v=2.27.14" media="meaningless-media-query" rel="stylesheet"/><link async="async" class="js-fa-async-stylesheets" href="https://fonts.googleapis.com/css?family=Marck+Script" media="meaningless-media-query" rel="stylesheet"/><script>setTimeout(window.lCSSAsync, 10);</script>
# <style>body{font-family:"Noto Sans",Arial,sans-serif;font-size:13px;line-height:1.42857143;color:#555;background-color:#fff}.container{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:768px){.container{width:750px}}@media (min-width:992px){.container{width:970px}}@media (min-width:1200px){.container{width:1170px}}.container-fluid{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.row{margin-left:-15px;margin-right:-15px}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{float:left}.col-xs-12{width:100%}.col-xs-11{width:91.66666667%}.col-xs-10{width:83.33333333%}.col-xs-9{width:75%}.col-xs-8{width:66.66666667%}.col-xs-7{width:58.33333333%}.col-xs-6{width:50%}.col-xs-5{width:41.66666667%}.col-xs-4{width:33.33333333%}.col-xs-3{width:25%}.col-xs-2{width:16.66666667%}.col-xs-1{width:8.33333333%}.col-xs-pull-12{right:100%}.col-xs-pull-11{right:91.66666667%}.col-xs-pull-10{right:83.33333333%}.col-xs-pull-9{right:75%}.col-xs-pull-8{right:66.66666667%}.col-xs-pull-7{right:58.33333333%}.col-xs-pull-6{right:50%}.col-xs-pull-5{right:41.66666667%}.col-xs-pull-4{right:33.33333333%}.col-xs-pull-3{right:25%}.col-xs-pull-2{right:16.66666667%}.col-xs-pull-1{right:8.33333333%}.col-xs-pull-0{right:auto}.col-xs-push-12{left:100%}.col-xs-push-11{left:91.66666667%}.col-xs-push-10{left:83.33333333%}.col-xs-push-9{left:75%}.col-xs-push-8{left:66.66666667%}.col-xs-push-7{left:58.33333333%}.col-xs-push-6{left:50%}.col-xs-push-5{left:41.66666667%}.col-xs-push-4{left:33.33333333%}.col-xs-push-3{left:25%}.col-xs-push-2{left:16.66666667%}.col-xs-push-1{left:8.33333333%}.col-xs-push-0{left:auto}.col-xs-offset-12{margin-left:100%}.col-xs-offset-11{margin-left:91.66666667%}.col-xs-offset-10{margin-left:83.33333333%}.col-xs-offset-9{margin-left:75%}.col-xs-offset-8{margin-left:66.66666667%}.col-xs-offset-7{margin-left:58.33333333%}.col-xs-offset-6{margin-left:50%}.col-xs-offset-5{margin-left:41.66666667%}.col-xs-offset-4{margin-left:33.33333333%}.col-xs-offset-3{margin-left:25%}.col-xs-offset-2{margin-left:16.66666667%}.col-xs-offset-1{margin-left:8.33333333%}.col-xs-offset-0{margin-left:0}@media (min-width:768px){.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9{float:left}.col-sm-12{width:100%}.col-sm-11{width:91.66666667%}.col-sm-10{width:83.33333333%}.col-sm-9{width:75%}.col-sm-8{width:66.66666667%}.col-sm-7{width:58.33333333%}.col-sm-6{width:50%}.col-sm-5{width:41.66666667%}.col-sm-4{width:33.33333333%}.col-sm-3{width:25%}.col-sm-2{width:16.66666667%}.col-sm-1{width:8.33333333%}.col-sm-pull-12{right:100%}.col-sm-pull-11{right:91.66666667%}.col-sm-pull-10{right:83.33333333%}.col-sm-pull-9{right:75%}.col-sm-pull-8{right:66.66666667%}.col-sm-pull-7{right:58.33333333%}.col-sm-pull-6{right:50%}.col-sm-pull-5{right:41.66666667%}.col-sm-pull-4{right:33.33333333%}.col-sm-pull-3{right:25%}.col-sm-pull-2{right:16.66666667%}.col-sm-pull-1{right:8.33333333%}.col-sm-pull-0{right:auto}.col-sm-push-12{left:100%}.col-sm-push-11{left:91.66666667%}.col-sm-push-10{left:83.33333333%}.col-sm-push-9{left:75%}.col-sm-push-8{left:66.66666667%}.col-sm-push-7{left:58.33333333%}.col-sm-push-6{left:50%}.col-sm-push-5{left:41.66666667%}.col-sm-push-4{left:33.33333333%}.col-sm-push-3{left:25%}.col-sm-push-2{left:16.66666667%}.col- ...
# <link href="https://yocket.in/profiles/bodepudi" rel="canonical"/>
# <meta content="Spring 2019 Student - GRE Score: 308, IELTS: 7, Undergrad: 81 % | Yocket" property="og:title"/> <meta content="Profile of study abroad  Spring 2019 student. GRE 308, Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam, Work Experience: 20 months, Interested in Computer Science and Engineering" property="og:description"/> <meta content="Yocket" property="og:site_name"/> <meta content="https://static.yocket.in/images/graphics/yocket-fb-share-og-image.png" property="og:image"/> <style id="antiClickjack">body{display:none !important;}</style>
# </head>
# <body class="body-unset" style="padding-top: 50px;">
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#         .text-white{
# 			color:white;
# 		}
#         .body-unset{
# 			padding-top: unset !important;
# 			overflow: hidden;
# 		}
#         .login-block-row{
#             background-color: #fff;
#             border-radius: 8px;
#             border-top: 4px solid #d66000;
#             padding-top: 10px;
#             padding-left: 5px;
#             padding-right: 5px;
#             padding-bottom: 15px;
#             margin: 0 auto;
#         }
#
#         /*Added for test*/
#         .overlay-content{
#             position: absolute;
#             left: 0;
#             right: 0;
#             margin: 0 auto;
#         }
#
#         .overlay{
#             height: 100%;
#             background: rgba(0,0,0,.5);
#             position: fixed;
#             z-index: 3000;
#             overflow-y: scroll;
#         }
#
#         .overlay{
# 			width: 103%;
# 		}
#
# 		.overlay-content{
# 			top: 8%;
# 		}
#
# 		@media screen and (min-width: 320px) and (max-width: 425px){
# 			.overlay{
# 				/* width: 120%; */
# 				width: 110%;
# 			}
# 		}
#
#         ::-webkit-scrollbar {
#             width: 0px;  /* remove scrollbar space */
#             background: transparent;  /* optional: just make scrollbar invisible */
#         }
#         /* optional: show position indicator in red */
#         ::-webkit-scrollbar-thumb {
#             background: #FF9800;
#         }
#
#         /* Datalist arrow hide*/
#         input#email::-webkit-calendar-picker-indicator {
#             display: none;
#         }
#
#
#     </style>
# <div class="overlay row" style="display: none;">
# <div class="overlay-content col-sm-6 col-xs-12 col-md-4 col-lg-4 text-center">
# <div class="row login-block-row">
# <div class="col-xs-12 col-sm-12">
# <div class="text-center" id="head">
# <h3><b>Welcome to Yocket</b></h3>
# <h4><small>Create your profile to connect with 40K aspirants!<br/> Your great story begins here...</small></h4>
# </div>
# <hr/>
# <form accept-charset="utf-8" action="/account/login" id="form-login-signup" method="post"><div style="display:none;"><input name="_method" type="hidden" value="POST"/><input autocomplete="off" name="_csrfToken" type="hidden" value="c60507a3c51127c809fa8234d43fa3a4c8f2ab959aab79cf42a375b0793ad8a4ab9fb86fb702725b50246202800485916a0d351d47e78aeb188fae43c2e41886"/></div> <div id="email_group">
# <div class="form-group" id="email_input_div">
# <input class="form-control input-lg" id="email" name="email" placeholder="eg. something@gmail.com" type="email"/>
# <span class="hidden text-danger" id="email_error">Please enter a valid email address</span>
# </div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_email" type="button">NEXT</button>
# <div>
# <br/>
# <div class="text-center">OR</div>
# <div style="padding: 1em 0;">
# <div class="row" style="margin: 0; padding: 0;">
# <div class="col col-md-12" style="margin: 0; padding: 0;">
# <button class="btn btn-default btn-block" id="google-login-button" style="font-size: 1.2em; padding: .5em 0; background-color: #fff; border-width: 2px;" type="button">
# <img alt="" src="https://static.yocket.in/images/graphics/google-logo.png" width="24"/>
# <span style="font-size: .9em;">Sign in with Google</span>
# </button>
# <div class="text-danger error hide js-error"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="password_group">
# <div class="alert alert-info hidden js-social-login-message"></div>
# <div class="form-group" id="email_input_div">
# <input class="form-control input-lg" id="password" name="password" placeholder="Enter your password" required="required" type="password"/>
# </div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." disabled="disabled" id="users_login_password" type="submit">SIGN IN</button>
# <div class="pull-right"><button class="btn btn-link" id="users_login_forgot_password" type="button">Forgot password?</button></div>
# <br/><br/>
# <div class="text-center">OR</div>
# <div style="padding: 1em 0;">
# <div class="row" style="margin: 0; padding: 0;">
# <div class="col col-md-12" style="margin: 0; padding: 0;">
# <button class="btn btn-default btn-block" id="google-login" style="font-size: 1.2em; padding: .5em 0; background-color: #fff; border-width: 2px;" type="button">
# <img alt="" src="https://static.yocket.in/images/graphics/google-logo.png" width="24"/>
# <span style="font-size: .9em;">Sign in with Google</span>
# </button>
# <div class="text-danger error hide js-error"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="verification_code_group">
# <p>A verification code has been sent to your email address</p>
# <div class="form-group" id="verification_code_input_div">
# <input class="form-control input-lg" id="verification_code" maxlength="4" placeholder="Enter verification code" type="tel"/>
# </div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_verification_code" type="button">CONTINUE</button>
# <span class="hidden text-danger" id="verification_code_error">We couldn't verify this code. Please enter the correct code and try again.</span>
# </div>
# <div class="hidden" id="create_account_group">
# <div class="form-group alert alert-danger error-msg-block">
# <span id="create_account_error">Please complete all fields correctly</span>
# </div>
# <div class="form-group">
# <input class="form-control input-lg" id="name" maxlength="24" placeholder="Name" type="text"/>
# </div>
# <div class="form-group">
# <input class="form-control input-lg" id="create_account_password" placeholder="Password" type="password"/>
# </div>
# <div class="form-group">
# <input class="form-control input-lg" id="signup_source" type="hidden" value="w"/>
# </div>
# <div class="form-group">
# <div class="row" style="padding: 0 1.5rem;">
# <div class="col-xs-12 col-sm-12 col-md-3 col-lg-3" style="padding: 0;">
# <select class="form-control input-lg" id="phone_calling_code" name="phone_calling_code" style="padding: .5em; font-size: 1.1em;"><option value="1">(+1) United States</option><option value="20">(+20) Egypt</option><option value="211">(+211) South Sudan</option><option value="212">(+212) Morocco</option><option value="213">(+213) Algeria</option><option value="216">(+216) Tunisia</option><option value="218">(+218) Libya</option><option value="220">(+220) Gambia</option><option value="221">(+221) Senegal</option><option value="222">(+222) Mauritania</option><option value="223">(+223) Mali</option><option value="224">(+224) Guinea</option><option value="225">(+225) Côte D'Ivoire</option><option value="226">(+226) Burkina Faso</option><option value="227">(+227) Niger</option><option value="228">(+228) Togo</option><option value="229">(+229) Benin</option><option value="230">(+230) Mauritius</option><option value="231">(+231) Liberia</option><option value="232">(+232) Sierra Leone</option><option value="233">(+233) Ghana</option><option value="234">(+234) Nigeria</option><option value="235">(+235) Chad</option><option value="237">(+237) Cameroon</option><option value="238">(+238) Cape Verde</option><option value="239">(+239) Sao Tome and Principe</option><option value="240">(+240) Equatorial Guinea</option><option value="241">(+241) Gabon</option><option value="243">(+243) Democratic Republic of Congo</option><option value="244">(+244) Angola</option><option value="245">(+245) Guinea Bissau</option><option value="248">(+248) Seychelles</option><option value="249">(+249) Sudan</option><option value="250">(+250) Rwanda</option><option value="251">(+251) Ethiopia</option><option value="252">(+252) Somalia</option><option value="253">(+253) Djibouti</option><option value="254">(+254) Kenya</option><option value="255">(+255) Tanzania</option><option value="256">(+256) Uganda</option><option value="257">(+257) Burundi</option><option value="258">(+258) Mozambique</option><option value="260">(+260) Zambia</option><option value="261">(+261) Madagascar</option><option value="263">(+263) Zimbabwe</option><option value="264">(+264) Namibia</option><option value="265">(+265) Malawi</option><option value="266">(+266) Lesotho</option><option value="267">(+267) Botswana</option><option value="268">(+268) Swaziland</option><option value="269">(+269) Comoros</option><option value="27">(+27) South Africa</option><option value="291">(+291) Eritrea</option><option value="30">(+30) Greece</option><option value="31">(+31) Netherlands</option><option value="32">(+32) Belgium</option><option value="33">(+33) France</option><option value="34">(+34) Spain</option><option value="351">(+351) Portugal</option><option value="352">(+352) Luxembourg</option><option value="353">(+353) Ireland</option><option value="354">(+354) Iceland</option><option value="355">(+355) Albania</option><option value="356">(+356) Malta</option><option value="357">(+357) Cyprus</option><option value="358">(+358) Finland</option><option value="359">(+359) Bulgaria</option><option value="36">(+36) Hungary</option><option value="370">(+370) Lithuania</option><option value="371">(+371) Latvia</option><option value="372">(+372) Estonia</option><option value="373">(+373) Moldova</option><option value="374">(+374) Armenia</option><option value="375">(+375) Belarus</option><option value="376">(+376) Andorra</option><option value="377">(+377) Monaco</option><option value="378">(+378) San Marino</option><option value="380">(+380) Ukraine</option><option value="381">(+381) Serbia</option><option value="382">(+382) Montenegro</option><option value="385">(+385) Croatia</option><option value="386">(+386) Slovenia</option><option value="387">(+387) Bosnia and Herzegovina</option><option value="389">(+389) Macedonia</option><option value="39">(+39) Italy</option><option value="40">(+40) Romania</option><option value="41">(+41) Switzerland</option><option value="420">(+420) Czech Republic</option><opt ...
# <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9" style="padding: 0;">
# <div class="input tel"><input class="form-control input-lg" id="phone" name="phone" placeholder="Your phone no." type="tel"/></div> </div>
# <span class="text-danger phone-exist-suggestion"></span>
# </div>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdMaBcTAAAAABUo_kEYOzkabZcx1-IvtSbb1W9Y"></div><br/>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_create_account" type="button">SIGN UP</button>
# <span class="hidden text-danger" id="create_account_error">Please complete all fields correctly</span>
# <br/><p><small>By creating an account you agree to Yocket's <a href="/about/terms" target="_blank">Terms of use</a> and <a href="/about/privacy" target="_blank">Privacy policy</a></small></p>
# </div>
# <div class="hidden text-center" id="users_login_loading_icon"><br/><i class="fa fa-spinner fa-pulse fa-2x"></i></div>
# </form>
# <br/>
# </div>
# </div>
# </div>
# </div>
# <div class="modal" id="element-modal" style="display: none; z-index: 3000;">
# <div class="modal-dialog" id="element-modal-dialog">
# <div class="modal-content">
# <div class="modal-header bg-primary" style="border-top-left-radius: 6px; border-top-right-radius: 6px;">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="element-modal-title"></h4>
# </div>
# <div class="modal-body text-justify" id="element-modal-body">
# </div>
# <div class="modal-footer">
# <button class="btn btn-primary text-capitalize" id="element-modal-btn-confirm" type="button"></button>
# <button class="btn btn-default text-capitalize" id="element-modal-btn-cancel" type="button"></button>
# </div>
# </div>
# </div>
# </div>
# <style>
# 	.padding-4 {
# 		padding: 4px;
# 		padding-right: .6em;
# 	}
# </style>
# <script>
# /**
# $jQ(document).ready(function(e) {
# 	$jQ(".ga-event").click(function(ev) {
# 		ev.preventDefault();
# 		var url = $jQ(this).attr('href');
# 		setTimeout(function () { window.location.href = url; }, 1000);
#
# 		var event_category = $jQ(this).data("event-category");
# 		var event_action = $jQ(this).data("event-action");
# 		var event_label = $jQ(this).data("event-label");
# 		ga('send', 'event', event_category, event_action, event_label, {
# 			hitCallback: function() {
# 			  window.location.href = url;
# 			}
# 		});
# 	});
# });
# */
# </script>
# <style>
# 	.skiptranslate iframe {
# 		display: none;
# 	}
# 	.translator-container {
#
# 	}
# </style>
# <div class="translator-container js-translator-container"></div>
# <nav class="navbar navbar-default navbar-fixed-top">
# <div class="container">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/">Yocket <div class="navbar-brand--subhead">by Stupidsid</div></a> </div>
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li><a href="/">
# <span class="fa fa-home"></span>
# </a></li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">UNIVERSITIES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="UniversityReviews" href="/universities"><i class="fa fa-chart-bar padding-4"></i> University Reviews</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="UniversityDeadlines" href="/university-application-deadlines"><i class="fa fa-clock padding-4"></i> University Deadlines</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="ProfileEvaluator" href="/university-courses/recommend"><i class="fa fa-graduation-cap padding-4"></i> Grad School Finder</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="CompareUniversities" href="/universities/compare"><i class="fa fa-balance-scale padding-4"></i> Compare Universities</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Courses" data-event-label="CourseDescriptions" href="/course-descriptions"><i class="fa fa-book padding-4"></i> Course Descriptions</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">PROFILES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Profiles" data-event-label="SimilarProfiles" href="/profiles/find/matching-profiles"><i class="fa fa-users padding-4"></i> Similar Profiles</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Profiles" data-event-label="AdmitsRejects" href="/profiles/find/matching-admits-and-rejects"><i class="fa fa-tags padding-4"></i> Admits &amp; Rejects</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/profiles/find"><i class="fa fa-search padding-4"></i> Find Profiles</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/profiles/find-roommates"><i class="fa fa-home padding-4"></i> Roommate Finder</a></li>
# </ul>
# </li>
# <li><a href="/discussions/home">DISCUSSIONS</a></li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">SERVICES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/services/mail"><i class="fa fa-paper-plane padding-4"></i> Send transcripts</a></li>
# <li><a href="/services/mail/orders"><i class="fa fa-shopping-cart padding-4"></i> Transcripts orders</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/services/loan-assistance"><i class="fa fa-hand-holding-usd padding-4"></i>Education Loans</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/services/forex?type=forex"><i class="fa fa-credit-card padding-4"></i> Forex Card</a></li>
# <li><a href="/services/forex?type=fees"><i class="fa fa-file-invoice-dollar padding-4"></i> University fee payment</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/fs/yocket-insurance-details-23"><i class="fa fa-medkit padding-4"></i> Health/Travel Insurance</a></li>
# </ul>
# </li>
# <li><a href="/events">EVENTS</a></li>
# <li><a href="/blog">BLOG</a></li>
# </ul>
# <form class="navbar-form navbar-right">
# <a href="/account/login"><button class="btn btn-primary" type="button">Login</button></a> <a class="ga-event" data-event-action="Navigate" data-event-category="Users" data-event-label="SignUp" href="/account/login"><button class="btn btn-default" type="button">Sign up</button></a> </form>
# </div>
# </div>
# </nav>
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 university-header" style="background-image: url('https://static.yocket.in/images/universities/backgrounds/utd.jpg');">
# <div class="col-sm-12" style="align-self: center;">
# <h1>University of Texas at Dallas aspirant</h1>
# <h4>Interested in Computer Science and Engineering (Spring 2019)</h4>
# </div>
# </div>
# </div>
# </div>
# <br/>
# <div class="container">
# <div class="row">
# <div class="col-sm-9">
# <div class="row">
# <div class="col-sm-6">
# <div class="col-sm-12">
# <h3>
# PROFILE &amp; ACADEMICS
# </h3>
# <hr/>
# <div class="row">
# <div class="col-sm-12">
# <strong>Undergrad:</strong><br/>
# Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam </div>
# </div><br/>
# <div class="row text-center">
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-globe fa-3x text-warning"></i>
# <h3>
# <small>GRE</small><br/> 308 <br/>
# <span style="display:inline-block; line-height:1.5; font-size: 0.5em;">
# Quant: 168<br/>
# Verbal: 140 </span>
# </h3>
# </div>
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-book fa-3x text-warning"></i>
# <h3><small>IELTS</small><br/>7</h3>
# </div>
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-graduation-cap fa-3x text-warning"></i>
# <h3><small>UG Score</small><br/>81%</h3>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="row text-center">
# <div class="col-sm-4 col-xs-4">
# <br/>
# <i class="fa fa-briefcase fa-3x text-warning"></i>
# <h4><small>Work Exp.</small><br/>20 months</h4>
# </div>
# <div class="col-sm-4 col-xs-4">
# <br/>
# <i class="fa fa-line-chart fa-3x text-warning"></i>
# <h4><small>Tech Papers</small><br/>NA</h4>
# </div>
# <div class="col-sm-4 col-xs-4">
# <br/>
# <i class="fa fa-university fa-3x text-warning"></i>
# <h4><small>Dream Univ.</small><br/>UTD</h4>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <div class="col-sm-6">
# <h3>
# UNIVERSITIES APPLIED
# </h3>
# <br/>
# <div class="responsive" id="application-statuses-div">
# <table class="table">
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-alabama-huntsville/business-analytics-25648">
# University of Alabama, Huntsville<br/>
# <small>Business Analytics</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-info">APPLIED</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/northeastern-university/information-systems-913">
# Northeastern University<br/>
# <small>Information Systems</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-info">APPLIED</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-dallas/information-technology-and-management-26891">
# University of Texas at Dallas<br/>
# <small>Information Technology and Management</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>09 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/bradley-university/computer-science-1821">
# Bradley University<br/>
# <small>Computer Science</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>15 Jun 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-arlington/computer-science-344">
# University of Texas at Arlington<br/>
# <small>Computer Science</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>17 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-dallas/management-information-system-199">
# University of Texas at Dallas<br/>
# <small>Management Information System</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>09 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-missouri-kansas-city/computer-science-2540">
# University of Missouri, Kansas City<br/>
# <small>Computer Science</small>
# </a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>07 Jun 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# </table>
# </div>
# <div class="alert alert-info">
# <div class="text-center">
# <h4>Talk to this University of Texas at Dallas aspirant on Yocket mobile app</h4>
# <a class="ga-event" data-event-action="Download" data-event-category="Outbound" data-event-label="YocketApp" href="https://play.google.com/store/apps/details?id=in.yocket&amp;referrer=utm_source%3Dyocket%26utm_medium%3Dwebapp%26utm_campaign%3Duserprofile" target="_blank">
# <img alt="Google Play" src="https://static.yocket.in/images/misc/google_play_download.png" style="padding: 8px; max-width: 160px; height: auto;"/> </a>
# <a class="ga-event" data-event-action="Download" data-event-category="Outbound" data-event-label="YocketApp" href="https://click.google-analytics.com/redirect?tid=UA-61697801-2&amp;url=https%3A%2F%2Fitunes.apple.com%2Fin%2Fapp%2Fyocket%2Fid1077706861&amp;aid=in.yocket&amp;idfa=%{yocketer}&amp;cs=yocket&amp;cm=webapp&amp;ck=userprofile" target="_blank">
# <img alt="iOS App Store" src="https://static.yocket.in/images/misc/ios_appstore_download.png" style="padding: 8px; max-width: 160px; height: auto;"/> </a>
# </div>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# <div class="col-sm-3">
# <div class="col-sm-12">
# <div class="text-center">
# <a href="/profiles/bodepudi/discussions"><button class="btn btn-default btn-block btn-lg"> <i class="fa fa-question-circle fa-lg"></i> bodepudi's questions</button></a> </div>
# <br/>
# <div class="text-center">
# <a href="/profiles/bodepudi/discussion-comments"><button class="btn btn-default btn-block btn-lg"> <i class="fa fa-comments-o fa-lg"></i> bodepudi's comments</button></a> </div>
# <br/>
# <div class="panel panel-info">
# <div class="panel-heading text-center">
# <span class="panel-title">TRENDING YOCKETERS THIS WEEK</span>
# </div>
# <div class="panel-body text-center">
# <h4>
# <a class="username" data-user-id="350013" href="/profiles/anuraagbaishya" style="color: #1565C0;">@anuraagbaishya</a> <br/>
# <small>50 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="84227" href="/profiles/ankita25" style="color: #1565C0;">@ankita25</a> <br/>
# <small>25 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="390988" href="/profiles/sam1608" style="color: #1565C0;">@sam1608</a> <br/>
# <small>25 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="330507" href="/profiles/stk" style="color: #1565C0;">@stk</a> <br/>
# <small>19 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="402169" href="/profiles/McMasters" style="color: #1565C0;">@McMasters</a> <br/>
# <small>18 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="397152" href="/profiles/chandru999" style="color: #1565C0;">@chandru999</a> <br/>
# <small>15 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="405797" href="/profiles/Shivaprakashm" style="color: #1565C0;">@Shivaprakashm</a> <br/>
# <small>15 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="358743" href="/profiles/Vamsi-oi" style="color: #1565C0;">@Vamsi-oi</a> <br/>
# <small>13 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="376828" href="/profiles/evan.boddu" style="color: #1565C0;">@evan.boddu</a> <br/>
# <small>13 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="327879" href="/profiles/srishynu" style="color: #1565C0;">@srishynu</a> <br/>
# <small>12 comments</small>
# </h4>
# </div>
# </div>
# </div>
# <div style="padding-top: 16px;">
# <div class="col-sm-12">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <div id="div-gpt-ad-1486040951439-0" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-0'); });
#             </script>
# </div>
# <br/><br/>
# <div id="div-gpt-ad-1486040951439-1" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-1'); });
#             </script>
# </div>
# <br/><br/>
# <div id="div-gpt-ad-1486040951439-2" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-2'); });
#             </script>
# </div>
# <br/><br/>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-5512390705137507" data-ad-slot="9303728642/6835238112" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# <br/>
# <br/>
# <div class="hidden-md hidden-lg" style="height: 200px;"></div>
# <div class="hidden-sm hidden-md hidden-lg" style="height: 100px;"></div>
# <footer class="footer text-center clearfix">
# <div class="container clearfix">
# <div class="row clearfix">
# <div class="col-sm-12">
# <h4>Looking for help? <a class="btn btn-info" href="/contact-us" style="color:#fff;">CONTACT US</a></h4>
# </div>
# </div>
# <br/>
# <div class="row clearfix">
# <div class="col-sm-3 col-xs-6">
# <p><strong>STUDY ABROAD UNIVERSITIES</strong></p>
# <ul class="list-unstyled">
# <li><a href="/universities/study-in-usa/top-100">Top 100 Universities in USA</a></li>
# <li><a href="/universities/study-in-australia">Study in Australia</a></li>
# <li><a href="/universities/study-in-united-kingdom">Study in UK</a></li>
# <li><a href="/universities/study-in-canada">Universities in Canada</a></li>
# <li><a href="/universities/study-in-singapore">Study in Singapore</a></li>
# <li><a href="/universities/compare">Compare Universities</a></li>
# <li><a href="/universities">University Reviews</a></li>
# <li><a href="/university-application-deadlines">Application Deadlines</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>APPLICATION PROCESS</strong></p>
# <ul class="list-unstyled">
# <li>
# <a href="/blog/gre-preparation-guide-1/how-to-prepare-for-gre-3">How to prepare for GRE</a> </li>
# <li>
# <a href="/blog/gre-preparation-guide-1/gre-structure-and-pattern-2">GRE Exam</a> |
# <a href="/blog/toefl-ielts-preparation-guide-2/ielts-v-s-toefl-771">IELTS vs TOEFL</a> </li>
# <li>
# <a href="/blog/gmat-preparation-guide-3/how-to-prepare-for-gmat-12">How to prepare for GMAT</a> </li>
# <li>
# <a href="/blog/university-application-process-4/all-about-lors-17">LOR</a>
# | <a href="/blog/university-application-process-4/all-about-sop-18">SOP</a> | <a href="/blog/i-20-and-visa-5/documents-required-for-student-visa-interview-25">Visa Documents</a> </li>
# <li><a href="/blog/study-abroad-financing-6/total-expenses-for-ms-in-us-20">Cost for MS in US</a></li>
# <li><a href="/blog">More Articles</a></li>
# <li><a href="/course-descriptions">Course Descriptions</a></li>
# <li><a href="/profiles/find/matching-admits-and-rejects">Admits &amp; rejects</a></li>
# </ul>
# </div>
# <div class="visible-xs">
# <div class="clearfix"></div>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>EXPLORE YOCKET SERVICES</strong></p>
# <ul class="list-unstyled">
# <li><a href="/university-courses/recommend">Profile evaluator</a></li>
# <li><a href="/profiles/find/matching-profiles">Similar profiles</a></li>
# <li><a href="/profiles/find-roommates">Roommate finder</a></li>
# <li><a href="/discussions/home">Discussions</a></li>
# <li><a href="/services/mail">Send transcripts</a></li>
# <li><a href="/services/loan-assistance">Education Loans</a> | <a href="/services/forex">Forex Card</a></li>
# <li><a href="/services/forex">University fee payment</a></li>
# <li><a href="/fs/yocket-insurance-details-23">Health/Travel Insurance</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>MORE</strong></p>
# <ul class="list-unstyled">
# <li><a href="/contact-us">Contact us</a> </li>
# <li> <a href="/about/jobs">Work with us</a></li>
# <li><a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Facebook" href="https://www.facebook.com/yocketapp" target="_blank">Facebook</a> | <a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Twitter" href="https://twitter.com/yocketapp" target="_blank">Twitter</a></li>
# <li><a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="YouTube" href="https://www.youtube.com/channel/UC-cDK8t9TBFWEnCyoTYIR-Q" target="_blank">YouTube</a> | <a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Instagram" href="https://www.instagram.com/yocketapp" target="_blank">Instagram</a></li>
# <li><a href="/about/company">About Us</a></li>
# <li><a href="/about/campus-ambassador-program">Campus Ambassador</a></li>
# <li><a href="/about/privacy">Privacy</a> </li>
# <li> <a href="/about/terms">Terms</a></li>
# </ul>
# </div>
# </div>
# <br/>
# <div class="clearfix">
# <div id="google_translate_element_footer"></div>
# </div>
# <br/>
# </div>
# <div id="fb-root"></div>
# </footer>
# </body>
# </html>

# %%
def getStudentdata(student_soup):
    student_element = student_soup.findAll("div", {"class" : "col-sm-4 col-xs-4"})
    for tag in student_element:
        heading = tag.find("small").text #column heading
        print(heading)
        data = tag.findNext("br").next_sibling.string #value
        if(heading == "GRE"):
            gre = data
        elif(heading == "IELTS" or heading == "TOEFL" or heading == "ENG TEST"):
            ielts = data
        elif(heading == "UG Score"):
            cgpa = data
        elif(heading == "Work Exp."):
            workExp = data     
        print(data)
# Out:
# GRE
#  308
# IELTS
# 7
# UG Score
# 81%
# Work Exp.
#
#
# Tech Papers
#
#
# Dream Univ.

# %%
#redirecting to login -- not working why?
student_page =  requests.get(student_url, headers=headers, verify=False)
student_soup = soup(student_page.content, 'html.parser')
student_soup
# Out:
# C:\Users\lakshmib\AppData\Local\Continuum\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py:791: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.org/en/latest/security.html
#   InsecureRequestWarning)
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>Spring 2019 Student - GRE Score: 308, IELTS: 7, Undergrad: 81 % | Yocket</title>
# <meta content="Profile of study abroad  Spring 2019 student. GRE 308, Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam, Work Experience: 20 months, Interested in Computer Science and Engineering" name="description"/>
# <meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <script src="/cdn-cgi/apps/head/Mu6wVX4OcZ8KDPC4TGyjOacEUjg.js"></script><link href="/img/yocket.ico" rel="icon" type="image/x-icon"/><link href="/img/yocket.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="//static.yocket.in" rel="dns-prefetch"/>
# <link href="//yocket.in" rel="dns-prefetch"/>
# <link href="//maxcdn.bootstrapcdn.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <meta content="#EF6C00" name="theme-color"/><link href="https://static.yocket.in/images/yocket_logo.png" rel="icon" sizes="192x192"/>
# <link href="/manifest.json" rel="manifest"/>
# <noscript class="css-links-wrapper">
# <!--<link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css" class="js-fa-async-stylesheets" media="meaningless-media-query" async="async"/>-->
# <link async="async" class="js-fa-async-stylesheets" href="https://use.fontawesome.com/releases/v5.1.1/css/all.css" media="meaningless-media-query" rel="stylesheet"/> <link async="async" class="js-fa-async-stylesheets" href="https://fonts.googleapis.com/css?family=Noto+Sans:400,700" media="meaningless-media-query" rel="stylesheet"/></noscript>
# <script defer="defer" src="https://static.yocket.in/js/vendor.js?v=2.28.36"></script><script type="text/javascript">
# 	window.base_url = 'https://yocket.in/';
# 	window.username = '';
# </script>
# <script>
# 	window.reqAnimFr =
# 		(typeof window.requestAnimationFrame === 'function')?
# 			(function(fn) { window.requestAnimationFrame(function() { fn(); }); }):
# 			(function(fn) { setTimeout(fn, 10); });
#
# 	// Full load(if loaded, call, else, wait for loading)
# 	window.onFullLoad = function(_onLoad) {
# 		// Is it already loaded?
# 		if([ 'complete', 'interactive' ].indexOf(document.readyState) !== -1) {
# 			requestAnimationFrame(_onLoad);
# 		} else {
# 			window.addEventListener('DOMContentLoaded', _onLoad);
# 		}
# 	};
#
# 	(function(doc, win, raf) {
# 		'use strict';
# 		window.Array.from= window.Array.from || function(arr) { return window.Array.prototype.slice.call(arr, 0); };
#
# 		var $deferedLinks= doc.querySelector('.css-links-wrapper');
#
# 		function applyCSS($el) { if($el.getAttribute('media') !== 'all') $el.setAttribute('media', 'all'); }
#
# 		window.lCSSAsync= function () {
# 			var cls= 'js-fa-async-stylesheets';
# 			var $asyncLinks= doc.querySelectorAll('.' + cls) || [];
#
# 			for(var i= 0; i< $asyncLinks.length; i++) {
# 				var $el = $asyncLinks[i];
# 				var isLoaded = true;
# 				$el.classList.remove(cls);
#
# 				for(var j= 0; j < doc.styleSheets.length; j++) {
# 					var s = doc.styleSheets[j];
# 					if(s.href === $el.href && !('cssRules' in s)) {
# 						$el.addEventListener('load', applyCSS.bind(null, $el));
# 						isLoaded = false;
# 						break;
# 					}
# 				}
#
# 				if(isLoaded) raf(applyCSS.bind(null, $el));
# 			}
# 		};
#
# 		function lCSSDef() {
# 			raf(function() {
# 				var $div= doc.createElement('div');
# 				$div.innerHTML= $deferedLinks? $deferedLinks.textContent: '';
# 				doc.head.appendChild($div);
# 				window.lCSSAsync();
# 			});
# 		}
# 		doc.addEventListener('DOMContentLoaded', lCSSDef);
# 	})(document, window, window.reqAnimFr);
# </script>
# <script crossorigin="anonymous" defer="" integrity="sha512-K1qjQ+NcF2TYO/eI3M6v8EiNYZfA95pQumfvcVrTHtwQVDG+aHRqLi/ETn2uB+1JqwYqVG3LIvdm9lj6imS/pQ==" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.5/js/bootstrap.min.js"></script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-61697801-2', 'auto');  ga('send', 'pageview');
# </script>
# <script async="async" src="https://www.googletagservices.com/tag/js/gpt.js"></script>
# <script>
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
# </script>
# <script>
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/118013234/yocket-right-1', [300, 250], 'div-gpt-ad-1486040951439-0').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-2', [300, 250], 'div-gpt-ad-1486040951439-1').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-3', [300, 250], 'div-gpt-ad-1486040951439-2').addService(googletag.pubads());
#     googletag.defineSlot('/118013234/yocket-right-4', [300, 250], 'div-gpt-ad-1510292313192-3').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script>
#     !function(f,b,e,v,n,t,s)
#     {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#     n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#     if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#     n.queue=[];t=b.createElement(e);t.async=!0;
#     t.src=v;s=b.getElementsByTagName(e)[0];
#     s.parentNode.insertBefore(t,s)}(window,document,'script',
#     'https://connect.facebook.net/en_US/fbevents.js');
#      fbq('init', '2335918096634703');
#     fbq('track', 'PageView');
# </script>
# <noscript>
# <img height="1" src="https://www.facebook.com/tr?id=129716877531675&amp;ev=PageView
#     &amp;noscript=1" width="1"/>
# </noscript>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.crossorigin='anonymous';
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&version=v2.8&appId=812660582206420";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
# <link async="async" class="js-fa-async-stylesheets" href="https://static.yocket.in/css/style.css?v=2.27.14" media="meaningless-media-query" rel="stylesheet"/><link async="async" class="js-fa-async-stylesheets" href="https://fonts.googleapis.com/css?family=Marck+Script" media="meaningless-media-query" rel="stylesheet"/><script>setTimeout(window.lCSSAsync, 10);</script>
# <style>body{font-family:"Noto Sans",Arial,sans-serif;font-size:13px;line-height:1.42857143;color:#555;background-color:#fff}.container{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}@media (min-width:768px){.container{width:750px}}@media (min-width:992px){.container{width:970px}}@media (min-width:1200px){.container{width:1170px}}.container-fluid{margin-right:auto;margin-left:auto;padding-left:15px;padding-right:15px}.row{margin-left:-15px;margin-right:-15px}.col-lg-1,.col-lg-10,.col-lg-11,.col-lg-12,.col-lg-2,.col-lg-3,.col-lg-4,.col-lg-5,.col-lg-6,.col-lg-7,.col-lg-8,.col-lg-9,.col-md-1,.col-md-10,.col-md-11,.col-md-12,.col-md-2,.col-md-3,.col-md-4,.col-md-5,.col-md-6,.col-md-7,.col-md-8,.col-md-9,.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9,.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{position:relative;min-height:1px;padding-left:15px;padding-right:15px}.col-xs-1,.col-xs-10,.col-xs-11,.col-xs-12,.col-xs-2,.col-xs-3,.col-xs-4,.col-xs-5,.col-xs-6,.col-xs-7,.col-xs-8,.col-xs-9{float:left}.col-xs-12{width:100%}.col-xs-11{width:91.66666667%}.col-xs-10{width:83.33333333%}.col-xs-9{width:75%}.col-xs-8{width:66.66666667%}.col-xs-7{width:58.33333333%}.col-xs-6{width:50%}.col-xs-5{width:41.66666667%}.col-xs-4{width:33.33333333%}.col-xs-3{width:25%}.col-xs-2{width:16.66666667%}.col-xs-1{width:8.33333333%}.col-xs-pull-12{right:100%}.col-xs-pull-11{right:91.66666667%}.col-xs-pull-10{right:83.33333333%}.col-xs-pull-9{right:75%}.col-xs-pull-8{right:66.66666667%}.col-xs-pull-7{right:58.33333333%}.col-xs-pull-6{right:50%}.col-xs-pull-5{right:41.66666667%}.col-xs-pull-4{right:33.33333333%}.col-xs-pull-3{right:25%}.col-xs-pull-2{right:16.66666667%}.col-xs-pull-1{right:8.33333333%}.col-xs-pull-0{right:auto}.col-xs-push-12{left:100%}.col-xs-push-11{left:91.66666667%}.col-xs-push-10{left:83.33333333%}.col-xs-push-9{left:75%}.col-xs-push-8{left:66.66666667%}.col-xs-push-7{left:58.33333333%}.col-xs-push-6{left:50%}.col-xs-push-5{left:41.66666667%}.col-xs-push-4{left:33.33333333%}.col-xs-push-3{left:25%}.col-xs-push-2{left:16.66666667%}.col-xs-push-1{left:8.33333333%}.col-xs-push-0{left:auto}.col-xs-offset-12{margin-left:100%}.col-xs-offset-11{margin-left:91.66666667%}.col-xs-offset-10{margin-left:83.33333333%}.col-xs-offset-9{margin-left:75%}.col-xs-offset-8{margin-left:66.66666667%}.col-xs-offset-7{margin-left:58.33333333%}.col-xs-offset-6{margin-left:50%}.col-xs-offset-5{margin-left:41.66666667%}.col-xs-offset-4{margin-left:33.33333333%}.col-xs-offset-3{margin-left:25%}.col-xs-offset-2{margin-left:16.66666667%}.col-xs-offset-1{margin-left:8.33333333%}.col-xs-offset-0{margin-left:0}@media (min-width:768px){.col-sm-1,.col-sm-10,.col-sm-11,.col-sm-12,.col-sm-2,.col-sm-3,.col-sm-4,.col-sm-5,.col-sm-6,.col-sm-7,.col-sm-8,.col-sm-9{float:left}.col-sm-12{width:100%}.col-sm-11{width:91.66666667%}.col-sm-10{width:83.33333333%}.col-sm-9{width:75%}.col-sm-8{width:66.66666667%}.col-sm-7{width:58.33333333%}.col-sm-6{width:50%}.col-sm-5{width:41.66666667%}.col-sm-4{width:33.33333333%}.col-sm-3{width:25%}.col-sm-2{width:16.66666667%}.col-sm-1{width:8.33333333%}.col-sm-pull-12{right:100%}.col-sm-pull-11{right:91.66666667%}.col-sm-pull-10{right:83.33333333%}.col-sm-pull-9{right:75%}.col-sm-pull-8{right:66.66666667%}.col-sm-pull-7{right:58.33333333%}.col-sm-pull-6{right:50%}.col-sm-pull-5{right:41.66666667%}.col-sm-pull-4{right:33.33333333%}.col-sm-pull-3{right:25%}.col-sm-pull-2{right:16.66666667%}.col-sm-pull-1{right:8.33333333%}.col-sm-pull-0{right:auto}.col-sm-push-12{left:100%}.col-sm-push-11{left:91.66666667%}.col-sm-push-10{left:83.33333333%}.col-sm-push-9{left:75%}.col-sm-push-8{left:66.66666667%}.col-sm-push-7{left:58.33333333%}.col-sm-push-6{left:50%}.col-sm-push-5{left:41.66666667%}.col-sm-push-4{left:33.33333333%}.col-sm-push-3{left:25%}.col-sm-push-2{left:16.66666667%}.col- ...
# <link href="https://yocket.in/profiles/bodepudi" rel="canonical"/>
# <meta content="Spring 2019 Student - GRE Score: 308, IELTS: 7, Undergrad: 81 % | Yocket" property="og:title"/> <meta content="Profile of study abroad  Spring 2019 student. GRE 308, Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam, Work Experience: 20 months, Interested in Computer Science and Engineering" property="og:description"/> <meta content="Yocket" property="og:site_name"/> <meta content="https://static.yocket.in/images/graphics/yocket-fb-share-og-image.png" property="og:image"/> <style id="antiClickjack">body{display:none !important;}</style>
# </head>
# <body class="body-unset" style="padding-top: 50px;">
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <style>
#         .text-white{
# 			color:white;
# 		}
#         .body-unset{
# 			padding-top: unset !important;
# 			overflow: hidden;
# 		}
#         .login-block-row{
#             background-color: #fff;
#             border-radius: 8px;
#             border-top: 4px solid #d66000;
#             padding-top: 10px;
#             padding-left: 5px;
#             padding-right: 5px;
#             padding-bottom: 15px;
#             margin: 0 auto;
#         }
#
#         /*Added for test*/
#         .overlay-content{
#             position: absolute;
#             left: 0;
#             right: 0;
#             margin: 0 auto;
#         }
#
#         .overlay{
#             height: 100%;
#             background: rgba(0,0,0,.5);
#             position: fixed;
#             z-index: 3000;
#             overflow-y: scroll;
#         }
#
#         .overlay{
# 			width: 103%;
# 		}
#
# 		.overlay-content{
# 			top: 8%;
# 		}
#
# 		@media screen and (min-width: 320px) and (max-width: 425px){
# 			.overlay{
# 				/* width: 120%; */
# 				width: 110%;
# 			}
# 		}
#
#         ::-webkit-scrollbar {
#             width: 0px;  /* remove scrollbar space */
#             background: transparent;  /* optional: just make scrollbar invisible */
#         }
#         /* optional: show position indicator in red */
#         ::-webkit-scrollbar-thumb {
#             background: #FF9800;
#         }
#
#         /* Datalist arrow hide*/
#         input#email::-webkit-calendar-picker-indicator {
#             display: none;
#         }
#
#
#     </style>
# <div class="overlay row" style="display: none;">
# <div class="overlay-content col-sm-6 col-xs-12 col-md-4 col-lg-4 text-center">
# <div class="row login-block-row">
# <div class="col-xs-12 col-sm-12">
# <div class="text-center" id="head">
# <h3><b>Welcome to Yocket</b></h3>
# <h4><small>Create your profile to connect with 40K aspirants!<br/> Your great story begins here...</small></h4>
# </div>
# <hr/>
# <form accept-charset="utf-8" action="/account/login" id="form-login-signup" method="post"><div style="display:none;"><input name="_method" type="hidden" value="POST"/><input autocomplete="off" name="_csrfToken" type="hidden" value="a1f65de3c12cfe8d778a0577028314be884e5ea2b6d205918f7e3d53dcfed1bd972917aaf89c5beab12dd1381c463a784cd0b5e8788140a4012dacffdf276ccc"/></div> <div id="email_group">
# <div class="form-group" id="email_input_div">
# <input class="form-control input-lg" id="email" name="email" placeholder="eg. something@gmail.com" type="email"/>
# <span class="hidden text-danger" id="email_error">Please enter a valid email address</span>
# </div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_email" type="button">NEXT</button>
# <div>
# <br/>
# <div class="text-center">OR</div>
# <div style="padding: 1em 0;">
# <div class="row" style="margin: 0; padding: 0;">
# <div class="col col-md-12" style="margin: 0; padding: 0;">
# <button class="btn btn-default btn-block" id="google-login-button" style="font-size: 1.2em; padding: .5em 0; background-color: #fff; border-width: 2px;" type="button">
# <img alt="" src="https://static.yocket.in/images/graphics/google-logo.png" width="24"/>
# <span style="font-size: .9em;">Sign in with Google</span>
# </button>
# <div class="text-danger error hide js-error"></div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="password_group">
# <div class="alert alert-info hidden js-social-login-message"></div>
# <div class="form-group" id="email_input_div">
# <input class="form-control input-lg" id="password" name="password" placeholder="Enter your password" required="required" type="password">
# </input></div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." disabled="disabled" id="users_login_password" type="submit">SIGN IN</button>
# <div class="pull-right"><button class="btn btn-link" id="users_login_forgot_password" type="button">Forgot password?</button></div>
# <br/><br/>
# <div class="text-center">OR</div>
# <div style="padding: 1em 0;">
# <div class="row" style="margin: 0; padding: 0;">
# <div class="col col-md-12" style="margin: 0; padding: 0;">
# <button class="btn btn-default btn-block" id="google-login" style="font-size: 1.2em; padding: .5em 0; background-color: #fff; border-width: 2px;" type="button">
# <img alt="" src="https://static.yocket.in/images/graphics/google-logo.png" width="24"/>
# <span style="font-size: .9em;">Sign in with Google</span>
# </button>
# <div class="text-danger error hide js-error"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden" id="verification_code_group">
# <p>A verification code has been sent to your email address</p>
# <div class="form-group" id="verification_code_input_div">
# <input class="form-control input-lg" id="verification_code" maxlength="4" placeholder="Enter verification code" type="tel">
# </input></div>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_verification_code" type="button">CONTINUE</button>
# <span class="hidden text-danger" id="verification_code_error">We couldn't verify this code. Please enter the correct code and try again.</span>
# </div>
# <div class="hidden" id="create_account_group">
# <div class="form-group alert alert-danger error-msg-block">
# <span id="create_account_error">Please complete all fields correctly</span>
# </div>
# <div class="form-group">
# <input class="form-control input-lg" id="name" maxlength="24" placeholder="Name" type="text">
# </input></div>
# <div class="form-group">
# <input class="form-control input-lg" id="create_account_password" placeholder="Password" type="password">
# </input></div>
# <div class="form-group">
# <input class="form-control input-lg" id="signup_source" type="hidden" value="w">
# </input></div>
# <div class="form-group">
# <div class="row" style="padding: 0 1.5rem;">
# <div class="col-xs-12 col-sm-12 col-md-3 col-lg-3" style="padding: 0;">
# <select class="form-control input-lg" id="phone_calling_code" name="phone_calling_code" style="padding: .5em; font-size: 1.1em;"><option value="1">(+1) United States</option><option value="20">(+20) Egypt</option><option value="211">(+211) South Sudan</option><option value="212">(+212) Morocco</option><option value="213">(+213) Algeria</option><option value="216">(+216) Tunisia</option><option value="218">(+218) Libya</option><option value="220">(+220) Gambia</option><option value="221">(+221) Senegal</option><option value="222">(+222) Mauritania</option><option value="223">(+223) Mali</option><option value="224">(+224) Guinea</option><option value="225">(+225) Côte D'Ivoire</option><option value="226">(+226) Burkina Faso</option><option value="227">(+227) Niger</option><option value="228">(+228) Togo</option><option value="229">(+229) Benin</option><option value="230">(+230) Mauritius</option><option value="231">(+231) Liberia</option><option value="232">(+232) Sierra Leone</option><option value="233">(+233) Ghana</option><option value="234">(+234) Nigeria</option><option value="235">(+235) Chad</option><option value="237">(+237) Cameroon</option><option value="238">(+238) Cape Verde</option><option value="239">(+239) Sao Tome and Principe</option><option value="240">(+240) Equatorial Guinea</option><option value="241">(+241) Gabon</option><option value="243">(+243) Democratic Republic of Congo</option><option value="244">(+244) Angola</option><option value="245">(+245) Guinea Bissau</option><option value="248">(+248) Seychelles</option><option value="249">(+249) Sudan</option><option value="250">(+250) Rwanda</option><option value="251">(+251) Ethiopia</option><option value="252">(+252) Somalia</option><option value="253">(+253) Djibouti</option><option value="254">(+254) Kenya</option><option value="255">(+255) Tanzania</option><option value="256">(+256) Uganda</option><option value="257">(+257) Burundi</option><option value="258">(+258) Mozambique</option><option value="260">(+260) Zambia</option><option value="261">(+261) Madagascar</option><option value="263">(+263) Zimbabwe</option><option value="264">(+264) Namibia</option><option value="265">(+265) Malawi</option><option value="266">(+266) Lesotho</option><option value="267">(+267) Botswana</option><option value="268">(+268) Swaziland</option><option value="269">(+269) Comoros</option><option value="27">(+27) South Africa</option><option value="291">(+291) Eritrea</option><option value="30">(+30) Greece</option><option value="31">(+31) Netherlands</option><option value="32">(+32) Belgium</option><option value="33">(+33) France</option><option value="34">(+34) Spain</option><option value="351">(+351) Portugal</option><option value="352">(+352) Luxembourg</option><option value="353">(+353) Ireland</option><option value="354">(+354) Iceland</option><option value="355">(+355) Albania</option><option value="356">(+356) Malta</option><option value="357">(+357) Cyprus</option><option value="358">(+358) Finland</option><option value="359">(+359) Bulgaria</option><option value="36">(+36) Hungary</option><option value="370">(+370) Lithuania</option><option value="371">(+371) Latvia</option><option value="372">(+372) Estonia</option><option value="373">(+373) Moldova</option><option value="374">(+374) Armenia</option><option value="375">(+375) Belarus</option><option value="376">(+376) Andorra</option><option value="377">(+377) Monaco</option><option value="378">(+378) San Marino</option><option value="380">(+380) Ukraine</option><option value="381">(+381) Serbia</option><option value="382">(+382) Montenegro</option><option value="385">(+385) Croatia</option><option value="386">(+386) Slovenia</option><option value="387">(+387) Bosnia and Herzegovina</option><option value="389">(+389) Macedonia</option><option value="39">(+39) Italy</option><option value="40">(+40) Romania</option><option value="41">(+41) Switzerland</option><option value="420">(+420) Czech Republic</option><opt ...
# <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9" style="padding: 0;">
# <div class="input tel"><input class="form-control input-lg" id="phone" name="phone" placeholder="Your phone no." type="tel"/></div> </div>
# <span class="text-danger phone-exist-suggestion"></span>
# </div>
# </div>
# <div class="g-recaptcha" data-sitekey="6LdMaBcTAAAAABUo_kEYOzkabZcx1-IvtSbb1W9Y"></div><br>
# <button class="btn btn-warning btn-lg btn-block" data-loading-text="..." id="users_login_create_account" type="button">SIGN UP</button>
# <span class="hidden text-danger" id="create_account_error">Please complete all fields correctly</span>
# <br><p><small>By creating an account you agree to Yocket's <a href="/about/terms" target="_blank">Terms of use</a> and <a href="/about/privacy" target="_blank">Privacy policy</a></small></p>
# </br></br></div>
# <div class="hidden text-center" id="users_login_loading_icon"><br/><i class="fa fa-spinner fa-pulse fa-2x"></i></div>
# </form>
# <br/>
# </div></div></div></div></body></html>
#
#
#
#
# <div class="modal" id="element-modal" style="display: none; z-index: 3000;">
# <div class="modal-dialog" id="element-modal-dialog">
# <div class="modal-content">
# <div class="modal-header bg-primary" style="border-top-left-radius: 6px; border-top-right-radius: 6px;">
# <button class="close" data-dismiss="modal" type="button">×</button>
# <h4 class="modal-title" id="element-modal-title"></h4>
# </div>
# <div class="modal-body text-justify" id="element-modal-body">
# </div>
# <div class="modal-footer">
# <button class="btn btn-primary text-capitalize" id="element-modal-btn-confirm" type="button"></button>
# <button class="btn btn-default text-capitalize" id="element-modal-btn-cancel" type="button"></button>
# </div>
# </div>
# </div>
# </div>
# <style>
# 	.padding-4 {
# 		padding: 4px;
# 		padding-right: .6em;
# 	}
# </style>
# <script>
# /**
# $jQ(document).ready(function(e) {
# 	$jQ(".ga-event").click(function(ev) {
# 		ev.preventDefault();
# 		var url = $jQ(this).attr('href');
# 		setTimeout(function () { window.location.href = url; }, 1000);
#
# 		var event_category = $jQ(this).data("event-category");
# 		var event_action = $jQ(this).data("event-action");
# 		var event_label = $jQ(this).data("event-label");
# 		ga('send', 'event', event_category, event_action, event_label, {
# 			hitCallback: function() {
# 			  window.location.href = url;
# 			}
# 		});
# 	});
# });
# */
# </script>
# <style>
# 	.skiptranslate iframe {
# 		display: none;
# 	}
# 	.translator-container {
#
# 	}
# </style>
# <div class="translator-container js-translator-container"></div>
# <nav class="navbar navbar-default navbar-fixed-top">
# <div class="container">
# <div class="navbar-header">
# <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="/">Yocket <div class="navbar-brand--subhead">by Stupidsid</div></a> </div>
# <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
# <ul class="nav navbar-nav">
# <li><a href="/">
# <span class="fa fa-home"></span>
# </a></li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">UNIVERSITIES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="UniversityReviews" href="/universities"><i class="fa fa-chart-bar padding-4"></i> University Reviews</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="UniversityDeadlines" href="/university-application-deadlines"><i class="fa fa-clock padding-4"></i> University Deadlines</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="ProfileEvaluator" href="/university-courses/recommend"><i class="fa fa-graduation-cap padding-4"></i> Grad School Finder</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Universities" data-event-label="CompareUniversities" href="/universities/compare"><i class="fa fa-balance-scale padding-4"></i> Compare Universities</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Courses" data-event-label="CourseDescriptions" href="/course-descriptions"><i class="fa fa-book padding-4"></i> Course Descriptions</a></li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">PROFILES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Profiles" data-event-label="SimilarProfiles" href="/profiles/find/matching-profiles"><i class="fa fa-users padding-4"></i> Similar Profiles</a></li>
# <li class="divider" role="separator"></li>
# <li><a class="ga-event" data-event-action="Navigate" data-event-category="Profiles" data-event-label="AdmitsRejects" href="/profiles/find/matching-admits-and-rejects"><i class="fa fa-tags padding-4"></i> Admits &amp; Rejects</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/profiles/find"><i class="fa fa-search padding-4"></i> Find Profiles</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/profiles/find-roommates"><i class="fa fa-home padding-4"></i> Roommate Finder</a></li>
# </ul>
# </li>
# <li><a href="/discussions/home">DISCUSSIONS</a></li>
# <li class="dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">SERVICES <span class="caret"></span>
# </a>
# <ul class="dropdown-menu">
# <li><a href="/services/mail"><i class="fa fa-paper-plane padding-4"></i> Send transcripts</a></li>
# <li><a href="/services/mail/orders"><i class="fa fa-shopping-cart padding-4"></i> Transcripts orders</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/services/loan-assistance"><i class="fa fa-hand-holding-usd padding-4"></i>Education Loans</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/services/forex?type=forex"><i class="fa fa-credit-card padding-4"></i> Forex Card</a></li>
# <li><a href="/services/forex?type=fees"><i class="fa fa-file-invoice-dollar padding-4"></i> University fee payment</a></li>
# <li class="divider" role="separator"></li>
# <li><a href="/fs/yocket-insurance-details-23"><i class="fa fa-medkit padding-4"></i> Health/Travel Insurance</a></li>
# </ul>
# </li>
# <li><a href="/events">EVENTS</a></li>
# <li><a href="/blog">BLOG</a></li>
# </ul>
# <form class="navbar-form navbar-right">
# <a href="/account/login"><button class="btn btn-primary" type="button">Login</button></a> <a class="ga-event" data-event-action="Navigate" data-event-category="Users" data-event-label="SignUp" href="/account/login"><button class="btn btn-default" type="button">Sign up</button></a> </form>
# </div>
# </div>
# </nav>
# <div class="container-fluid">
# <div class="row">
# <div class="col-sm-12 university-header" style="background-image: url('https://static.yocket.in/images/universities/backgrounds/utd.jpg');">
# <div class="col-sm-12" style="align-self: center;">
# <h1>University of Texas at Dallas aspirant</h1>
# <h4>Interested in Computer Science and Engineering (Spring 2019)</h4>
# </div>
# </div>
# </div>
# </div>
# <br>
# <div class="container">
# <div class="row">
# <div class="col-sm-9">
# <div class="row">
# <div class="col-sm-6">
# <div class="col-sm-12">
# <h3>
# PROFILE &amp; ACADEMICS
# </h3>
# <hr>
# <div class="row">
# <div class="col-sm-12">
# <strong>Undergrad:</strong><br>
# Electrical and Electronics Engineering from gayatri vidya parishad college of engineering, Visakhapatnam </br></div>
# </div><br>
# <div class="row text-center">
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-globe fa-3x text-warning"></i>
# <h3>
# <small>GRE</small><br> 308 <br>
# <span style="display:inline-block; line-height:1.5; font-size: 0.5em;">
# Quant: 168<br>
# Verbal: 140 </br></span>
# </br></br></h3>
# </div>
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-book fa-3x text-warning"></i>
# <h3><small>IELTS</small><br>7</br></h3>
# </div>
# <div class="col-sm-4 col-xs-4">
# <i class="fa fa-graduation-cap fa-3x text-warning"></i>
# <h3><small>UG Score</small><br>81%</br></h3>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="row text-center">
# <div class="col-sm-4 col-xs-4">
# <br>
# <i class="fa fa-briefcase fa-3x text-warning"></i>
# <h4><small>Work Exp.</small><br>20 months</br></h4>
# </br></div>
# <div class="col-sm-4 col-xs-4">
# <br>
# <i class="fa fa-line-chart fa-3x text-warning"></i>
# <h4><small>Tech Papers</small><br>NA</br></h4>
# </br></div>
# <div class="col-sm-4 col-xs-4">
# <br>
# <i class="fa fa-university fa-3x text-warning"></i>
# <h4><small>Dream Univ.</small><br>UTD</br></h4>
# </br></div>
# </div>
# <div class="clearfix"></div>
# </br></hr></div>
# </div>
# <div class="col-sm-6">
# <h3>
# UNIVERSITIES APPLIED
# </h3>
# <br>
# <div class="responsive" id="application-statuses-div">
# <table class="table">
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-alabama-huntsville/business-analytics-25648">
# University of Alabama, Huntsville<br>
# <small>Business Analytics</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-info">APPLIED</span></h4></td></tr></table></div></br></div></div></div></div></div></br>
#
#
#
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/northeastern-university/information-systems-913">
# Northeastern University<br>
# <small>Information Systems</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-info">APPLIED</span></h4></td></tr>
#
#
#
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-dallas/information-technology-and-management-26891">
# University of Texas at Dallas<br>
# <small>Information Technology and Management</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>09 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/bradley-university/computer-science-1821">
# Bradley University<br>
# <small>Computer Science</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>15 Jun 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-arlington/computer-science-344">
# University of Texas at Arlington<br>
# <small>Computer Science</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>17 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-texas-dallas/management-information-system-199">
# University of Texas at Dallas<br>
# <small>Management Information System</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>09 Jul 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
# <tr>
# <td>
# <h4>
# <a href="/graduate-programs/university-of-missouri-kansas-city/computer-science-2540">
# University of Missouri, Kansas City<br>
# <small>Computer Science</small>
# </br></a>
# </h4>
# <div class="row">
# <div class="col-sm-6">
# <small class="text-grey">
# Applied: <strong>28 May 2018</strong>
# </small>
# </div>
# <div class="col-sm-6">
# <small class="text-grey">
# Decision: <strong>07 Jun 2018</strong>
# </small>
# </div>
# <div class="col-sm-12">
# </div>
# </div>
# </td>
# <td class="text-center">
# <h4>
# <span class="label label-success">ADMIT</span>
# </h4>
# </td>
# </tr>
#
#
# <div class="alert alert-info">
# <div class="text-center">
# <h4>Talk to this University of Texas at Dallas aspirant on Yocket mobile app</h4>
# <a class="ga-event" data-event-action="Download" data-event-category="Outbound" data-event-label="YocketApp" href="https://play.google.com/store/apps/details?id=in.yocket&amp;referrer=utm_source%3Dyocket%26utm_medium%3Dwebapp%26utm_campaign%3Duserprofile" target="_blank">
# <img alt="Google Play" src="https://static.yocket.in/images/misc/google_play_download.png" style="padding: 8px; max-width: 160px; height: auto;"/> </a>
# <a class="ga-event" data-event-action="Download" data-event-category="Outbound" data-event-label="YocketApp" href="https://click.google-analytics.com/redirect?tid=UA-61697801-2&amp;url=https%3A%2F%2Fitunes.apple.com%2Fin%2Fapp%2Fyocket%2Fid1077706861&amp;aid=in.yocket&amp;idfa=%{yocketer}&amp;cs=yocket&amp;cm=webapp&amp;ck=userprofile" target="_blank">
# <img alt="iOS App Store" src="https://static.yocket.in/images/misc/ios_appstore_download.png" style="padding: 8px; max-width: 160px; height: auto;"/> </a>
# </div>
# </div>
#
#
# <div class="clearfix"></div>
#
# <div class="col-sm-3">
# <div class="col-sm-12">
# <div class="text-center">
# <a href="/profiles/bodepudi/discussions"><button class="btn btn-default btn-block btn-lg"> <i class="fa fa-question-circle fa-lg"></i> bodepudi's questions</button></a> </div>
# <br>
# <div class="text-center">
# <a href="/profiles/bodepudi/discussion-comments"><button class="btn btn-default btn-block btn-lg"> <i class="fa fa-comments-o fa-lg"></i> bodepudi's comments</button></a> </div>
# <br>
# <div class="panel panel-info">
# <div class="panel-heading text-center">
# <span class="panel-title">TRENDING YOCKETERS THIS WEEK</span>
# </div>
# <div class="panel-body text-center">
# <h4>
# <a class="username" data-user-id="350013" href="/profiles/anuraagbaishya" style="color: #1565C0;">@anuraagbaishya</a> <br/>
# <small>50 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="84227" href="/profiles/ankita25" style="color: #1565C0;">@ankita25</a> <br/>
# <small>25 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="390988" href="/profiles/sam1608" style="color: #1565C0;">@sam1608</a> <br/>
# <small>25 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="330507" href="/profiles/stk" style="color: #1565C0;">@stk</a> <br/>
# <small>19 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="402169" href="/profiles/McMasters" style="color: #1565C0;">@McMasters</a> <br/>
# <small>18 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="397152" href="/profiles/chandru999" style="color: #1565C0;">@chandru999</a> <br/>
# <small>15 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="405797" href="/profiles/Shivaprakashm" style="color: #1565C0;">@Shivaprakashm</a> <br/>
# <small>15 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="358743" href="/profiles/Vamsi-oi" style="color: #1565C0;">@Vamsi-oi</a> <br/>
# <small>13 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="376828" href="/profiles/evan.boddu" style="color: #1565C0;">@evan.boddu</a> <br/>
# <small>13 comments</small>
# </h4>
# <h4>
# <a class="username" data-user-id="327879" href="/profiles/srishynu" style="color: #1565C0;">@srishynu</a> <br/>
# <small>12 comments</small>
# </h4>
# </div>
# </div>
# </br></br></div>
# <div style="padding-top: 16px;">
# <div class="col-sm-12">
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <div id="div-gpt-ad-1486040951439-0" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-0'); });
#             </script>
# </div>
# <br/><br/>
# <div id="div-gpt-ad-1486040951439-1" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-1'); });
#             </script>
# </div>
# <br/><br/>
# <div id="div-gpt-ad-1486040951439-2" style="height:250px; width:300px;">
# <script>
#                 googletag.cmd.push(function() { googletag.display('div-gpt-ad-1486040951439-2'); });
#             </script>
# </div>
# <br/><br/>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-5512390705137507" data-ad-slot="9303728642/6835238112" style="display:inline-block;width:300px;height:250px"></ins>
# <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#         </script>
# </div>
# </div>
# </div>
# <div class="clearfix"></div>
#
#
# <br/>
# <br/>
# <div class="hidden-md hidden-lg" style="height: 200px;"></div>
# <div class="hidden-sm hidden-md hidden-lg" style="height: 100px;"></div>
# <footer class="footer text-center clearfix">
# <div class="container clearfix">
# <div class="row clearfix">
# <div class="col-sm-12">
# <h4>Looking for help? <a class="btn btn-info" href="/contact-us" style="color:#fff;">CONTACT US</a></h4>
# </div>
# </div>
# <br/>
# <div class="row clearfix">
# <div class="col-sm-3 col-xs-6">
# <p><strong>STUDY ABROAD UNIVERSITIES</strong></p>
# <ul class="list-unstyled">
# <li><a href="/universities/study-in-usa/top-100">Top 100 Universities in USA</a></li>
# <li><a href="/universities/study-in-australia">Study in Australia</a></li>
# <li><a href="/universities/study-in-united-kingdom">Study in UK</a></li>
# <li><a href="/universities/study-in-canada">Universities in Canada</a></li>
# <li><a href="/universities/study-in-singapore">Study in Singapore</a></li>
# <li><a href="/universities/compare">Compare Universities</a></li>
# <li><a href="/universities">University Reviews</a></li>
# <li><a href="/university-application-deadlines">Application Deadlines</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>APPLICATION PROCESS</strong></p>
# <ul class="list-unstyled">
# <li>
# <a href="/blog/gre-preparation-guide-1/how-to-prepare-for-gre-3">How to prepare for GRE</a> </li>
# <li>
# <a href="/blog/gre-preparation-guide-1/gre-structure-and-pattern-2">GRE Exam</a> |
# <a href="/blog/toefl-ielts-preparation-guide-2/ielts-v-s-toefl-771">IELTS vs TOEFL</a> </li>
# <li>
# <a href="/blog/gmat-preparation-guide-3/how-to-prepare-for-gmat-12">How to prepare for GMAT</a> </li>
# <li>
# <a href="/blog/university-application-process-4/all-about-lors-17">LOR</a>
# | <a href="/blog/university-application-process-4/all-about-sop-18">SOP</a> | <a href="/blog/i-20-and-visa-5/documents-required-for-student-visa-interview-25">Visa Documents</a> </li>
# <li><a href="/blog/study-abroad-financing-6/total-expenses-for-ms-in-us-20">Cost for MS in US</a></li>
# <li><a href="/blog">More Articles</a></li>
# <li><a href="/course-descriptions">Course Descriptions</a></li>
# <li><a href="/profiles/find/matching-admits-and-rejects">Admits &amp; rejects</a></li>
# </ul>
# </div>
# <div class="visible-xs">
# <div class="clearfix"></div>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>EXPLORE YOCKET SERVICES</strong></p>
# <ul class="list-unstyled">
# <li><a href="/university-courses/recommend">Profile evaluator</a></li>
# <li><a href="/profiles/find/matching-profiles">Similar profiles</a></li>
# <li><a href="/profiles/find-roommates">Roommate finder</a></li>
# <li><a href="/discussions/home">Discussions</a></li>
# <li><a href="/services/mail">Send transcripts</a></li>
# <li><a href="/services/loan-assistance">Education Loans</a> | <a href="/services/forex">Forex Card</a></li>
# <li><a href="/services/forex">University fee payment</a></li>
# <li><a href="/fs/yocket-insurance-details-23">Health/Travel Insurance</a></li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <p><strong>MORE</strong></p>
# <ul class="list-unstyled">
# <li><a href="/contact-us">Contact us</a> </li>
# <li> <a href="/about/jobs">Work with us</a></li>
# <li><a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Facebook" href="https://www.facebook.com/yocketapp" target="_blank">Facebook</a> | <a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Twitter" href="https://twitter.com/yocketapp" target="_blank">Twitter</a></li>
# <li><a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="YouTube" href="https://www.youtube.com/channel/UC-cDK8t9TBFWEnCyoTYIR-Q" target="_blank">YouTube</a> | <a class="ga-event" data-event-action="Click" data-event-category="SocialMedia" data-event-label="Instagram" href="https://www.instagram.com/yocketapp" target="_blank">Instagram</a></li>
# <li><a href="/about/company">About Us</a></li>
# <li><a href="/about/campus-ambassador-program">Campus Ambassador</a></li>
# <li><a href="/about/privacy">Privacy</a> </li>
# <li> <a href="/about/terms">Terms</a></li>
# </ul>
# </div>
# </div>
# <br/>
# <div class="clearfix">
# <div id="google_translate_element_footer"></div>
# </div>
# <br/>
# </div>
# <div id="fb-root"></div>
# </footer>
